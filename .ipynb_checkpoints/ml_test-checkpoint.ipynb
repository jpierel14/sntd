# %%
from matplotlib import pyplot as plt
import sncosmo
from sntd import simulation, fitting,io,ml
import scipy
from sntd.plotting import _COLORLIST5
import sys,pyParz
from copy import deepcopy
import numpy as np
from astropy.io import ascii
from scipy.interpolate import splrep,splev
from scipy.optimize import minimize,minimize_scalar
from scipy.interpolate import interp1d
import extinction
from sncosmo.utils import integration_grid
from sncosmo.constants import HC_ERG_AA, MODEL_BANDFLUX_SPACING
from statsmodels.stats.stattools import durbin_watson
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from astropy.table import Table
from scipy.interpolate import InterpolatedUnivariateSpline as Spline1d
import matplotlib.mlab as mlab

# %%
reload(ml)
kappa_list=np.linspace(.2,1.3,3)
shear_list=np.linspace(.2,1.3,3)
maxmass=10.
q=.2
fstar=.5
all_micro=[[],[],[]]
for i in range(len(kappa_list)):
    for j in range(len(shear_list)):
        kappa=kappa_list[i]
        shear=shear_list[j]
        all_micro[i].append(ml.realizeMicro(verbose=True,nray=500,kappas=fstar*kappa,gamma=shear,kappac=(1-fstar)*kappa,minmass=q*maxmass,maxmass=maxmass))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-1c873bfab88c> in <module>()
#      10         kappa=kappa_list[i]
#      11         shear=shear_list[j]
# ---> 12         all_micro[i].append(ml.realizeMicro(verbose=True,nray=500,kappas=fstar*kappa,gamma=shear,kappac=(1-fstar)*kappa,minmass=q*maxmass,maxmass=maxmass))
#      13
#      14
#
# /Users/jpierel/rodney/sntd/sntd/ml.pyc in realizeMicro(arand, debug, kappas, kappac, gamma, eps, nray, minmass, maxmass, power, pixmax, pixminx, pixminy, pixdif, fracpixd, iwrite, verbose)
#      75     num=np.loadtxt(os.path.join(__dir__,'microlens','jobnum'),dtype='str')
#      76     #lensPlane=np.array(fits.open(os.path.join(__dir__,'microlens','IRIS'+str(num)+'.fits'))[0].data,dtype=np.float64)
# ---> 77     lensPlane=fits.open(os.path.join(__dir__,'microlens','IRIS'+str(num)+'.fits'))[0].data
# ...

# %%
zl=.5
zs=1.4
for i in range(3):
    for j in range(3):
        
        time,dmag=ml.microcaustic_field_to_curve(all_micro[i][j],np.arange(0,100,1),zl,zs)

# %%
reload(ml)
kappa=.31
shear=.61
maxmass=10.
q=.2
fstar=.5
fitData=ml.realizeMicro(nray=500,kappas=fstar*kappa,gamma=shear,kappac=(1-fstar)*kappa,minmass=q*maxmass,maxmass=maxmass)
# Out:
# 1877

# %%
ascii.write(fitData,'test.dat')

# %%
zl=.5
zs=1.4
time,dmag=ml.microcaustic_field_to_curve(fitData,np.arange(0,100,1),zl,zs)

# %%
reload(ml)
mlList=[]
for i in range(len(fitData)):
    mlList.append([])
    for j in range(1000):
        time,dmag=ml.microcaustic_field_to_curve(fitData[i],np.arange(10,50,1),.5,1.3)
        mlList[i].append(dmag)

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,sharex=True,sharey=False,figsize=(20,30))
row=0
col=0
for i in range(len(fitData)):
    if i==1 or i==3:
        col=1
    elif i==2:
        row=1
        col=0
    for mag in mlList[i]:
        ax[row][col].plot(time,mag,color='k')
    ax[row][col].plot([29.5,29.5],ax[row][col].get_ylim(),'r--')
    ax[row][col].invert_yaxis()
plt.show()
plt.clf()
plt.close()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,sharex=True,sharey=False,figsize=(20,30))
row=0
col=0
for i in range(len(fitData)):
    if i==1 or i==3:
        col=1
    elif i==2:
        row=1
        col=0
    for mag in mlList[i]:
        ax[row][col].plot(time,mag-np.median(mag),color='k')
    ax[row][col].plot([29.5,29.5],ax[row][col].get_ylim(),'r--')
    ax[row][col].invert_yaxis()
plt.show()
plt.clf()
plt.close()

# %%
reload(simulation)
reload(sncosmo)
reload(fitting)
modname ='snana-2004gv'#
snType = 'Ib'
#bandlist = ['bessellb', 'bessellv', 'bessellr']
bandlist = ['F110W']
mod=sncosmo.Model(modname)
t=np.linspace(-5,10,100)
fig=plt.figure(figsize=(10,10))
ax=fig.gca()
lc1=mod.bandflux('bessellb',t)/np.max(mod.bandflux('bessellb',t))
lc2=mod.bandflux('bessellb',t-2)/np.max(mod.bandflux('bessellb',t-2))
mu=sncosmo.AchromaticMicrolensing(t,lc2/lc1)
mod.add_effect(mu,'microlensing','rest')
ax.plot(t,lc1,label='Model (No Microlensing)',linewidth=3)
ax.plot(t,mod.bandflux('bessellb',t)/np.max(mod.bandflux('bessellb',t)),label='Model (With Microlensing)',linewidth=3)
ax.plot(t,lc2,'g--',label='Shifted Model (No Microlensing)',linewidth=3)
ax_divider = make_axes_locatable(ax)
ax_ml = ax_divider.append_axes("bottom", size="25%", pad=.4)
ax_ml.plot(t,lc2/lc1,color='k',label='Microlensing ($\mu$)',linewidth=3)
ax_ml.set_xlabel('Time (Observer Frame Days)',fontsize=14)
ax_ml.set_ylabel('Magnification',fontsize=14)
ax_ml.legend(fontsize=14)
ax.set_ylabel('Normalized Flux',fontsize=14)
ax.legend(fontsize=14)
plt.show()
#plt.savefig('../manuscripts/SNTD_Manuscript/delays/FIG/pathological_micro.pdf',format='pdf',overwrite=True)
plt.close()

# %%
reload(simulation)
reload(sncosmo)
reload(fitting)
modname ='snana-2004gv'#
snType = 'Ib'
t=np.linspace(-5,10,1000)
#fig=plt.figure(figsize=(5,5))
#ax=fig.gca()
mod=sncosmo.Model(modname)

'''
lc1=mod.bandflux('bessellb',t)
t0=t[lc1==np.max(lc1)][0]
ax.plot(t,lc1/np.max(lc1),label='Model (No Microlensing)',linewidth=3,color='k')
ax_divider = make_axes_locatable(ax)
ax_ml = ax_divider.append_axes("bottom", size="25%", pad=.4)
for s in np.linspace(-.4/(t[-1]-t[0]),.4/(t[-1]-t[0]),4):
    mod2=sncosmo.Model(modname)
    mu=sncosmo.AchromaticMicrolensing(t,s*t+1)
    mod2.add_effect(mu,'microlensing','rest')
    ax.plot(t,mod2.bandflux('bessellb',t)/np.max(mod2.bandflux('bessellb',t)),
            label='Model (Slope='+str(np.round(np.sum(np.abs(np.gradient(s*t[t<=5]+1))),2))+')',linewidth=2)
    ax_ml.plot(t,s*t+1,label='Microlensing ($\mu$)',linewidth=2)

for s in np.linspace(.8,1.2,4):
    y2=(1.2-s)+.8
    mod2=sncosmo.Model(modname)
    ml=((y2-s)/(t[-1]**2-t[0]**2)*t**2+(y2-t[-1]**2*(y2-s)/(t[-1]**2-t[0]**2)))
    mu=sncosmo.AchromaticMicrolensing(t,ml)
    mod2.add_effect(mu,'microlensing','rest')
    ax.plot(t,mod2.bandflux('bessellb',t)/np.max(mod2.bandflux('bessellb',t)),'--',
            label='Model (Slope='+str(np.round(np.sum(np.abs(np.gradient(ml[t<=5]))),2))+')',linewidth=2)
    ax_ml.plot(t,ml,'--',label='Microlensing ($\mu$)',linewidth=2)
ax_ml.set_xlabel('Time (Observer Frame Days)',fontsize=14)
ax_ml.set_ylabel('Magnification',fontsize=14)
#ax_ml.legend(fontsize=14)
ax.set_ylabel('Normalized Flux',fontsize=14)
ax.legend(fontsize=14)
plt.show()
#plt.savefig('../manuscripts/SNTD_Manuscript/delays/FIG/pathological_micro.pdf',format='pdf',overwrite=True)
plt.close()
'''

nspl=1000
nanchor=4
sigmadm=.6
fig=plt.figure()
ax=fig.gca()
avsplineNum=1000
t0s=[]
mus=[]
mus2=[]
mus3=[]
mus4=[]
for i in range(1000):#s in np.linspace(-.5/(t[-1]-t[0]),.5/(t[-1]-t[0]),100):
    mod2=sncosmo.Model(modname)
    y1,y2=np.random.normal(1,.1,2)
    s=(y2-y1)/(t[-1]-t[0])
    b=np.random.normal(1,.2,1)
    ml=s*t+b
    if np.min(ml<.7) or np.max(ml>1.3):
        continue
    mu=sncosmo.AchromaticMicrolensing(t,ml)
    mod2.add_effect(mu,'microlensing','rest')
    tempFlux=mod2.bandflux('bessellb',t)
    tempt0=t[tempFlux==np.max(tempFlux)][0]
    '''
for i in range(nspl):
    splineset = []
    for j in range(avsplineNum):
        time_anchors = np.linspace(t[0], t[-1], nanchor)
        deltam_anchors = np.random.normal(1, sigmadm, len(time_anchors))
        spl1d = Spline1d(time_anchors, deltam_anchors)
        splineset.append(spl1d(t))
    tempspl = np.mean(np.array(splineset), 0)
    if np.max(tempspl)>1.2:
        tempspl*=(1.2/np.max(tempspl))
    if np.min(tempspl)<.8:
        tempspl*=(.8/np.min(tempspl))

    mod=sncosmo.Model(modname)
    mu=sncosmo.AchromaticMicrolensing(t,tempspl)
    mod.add_effect(mu,'microlensing','rest')
    tempFlux=mod.bandflux('bessellb',t)
    tempt0=t[tempFlux==np.max(tempFlux)][0]
    
    
    
    ''' 
    if np.abs(tempt0-t0)>1.7:
        print(np.sum(np.abs(np.gradient(ml[t<=3][t[t<=3]>=-3]))),np.abs(tempt0-t0),s,b)
        #fig=plt.figure()
        #ax=fig.gca()
        #ax.plot(t,ml)
        #plt.show()
    t0s.append(np.abs(tempt0-t0))
    mus=np.append(mus,np.abs(np.sum(np.gradient(ml[t<=3][t[t<=3]>=-3]))))
    mus2=np.append(mus2,np.sum(np.array(ml[t<=3][t[t<=3]>=-3]-np.median(ml[t<=3][t[t<=3]>=-3]))**2))
    mus3=np.append(mus3,np.abs((ml[t<=3][t[t<=3]>=-3][-1]-ml[t<=3][t[t<=3]>=-3][0])/6.))
    
    ax.scatter(np.abs(np.sum(np.gradient(ml[t<=3][t[t<=3]>=-3]))),np.abs(tempt0-t0),color='orange')
mus=np.array(mus)
mus2=np.array(mus2)
mus3=np.array(mus3)
t0s=np.array(t0s)

lstsq=scipy.stats.linregress(mus,t0s)
m=lstsq[0]
b=lstsq[1]
linear=interp1d(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100),m*np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)+b)
ax.plot(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100),m*np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)+b)
#from scipy.interpolate import Rbf
z=np.abs(t0s-linear(mus))
sort=np.argsort(mus)
mus=mus[sort]
t0s=t0s[sort]

allsigs=[0]
allVals=[0]
dmu=100
for i in np.arange(0,len(mus),dmu):
    mean,sigma=scipy.stats.norm.fit(t0s[i:min(i+dmu,len(mus))])
    allsigs.append(sigma)
    allVals.append(mus[min(i+dmu,len(mus)-1)])
sigFunc=interp1d(allVals,allsigs,fill_value='extrapolate',bounds_error=False)
ax.fill_between(np.linspace(np.min(mus),np.max(mus),100),
                linear(np.linspace(np.min(mus),np.max(mus),100))+
                    3*sigFunc(np.linspace(np.min(mus),np.max(mus),100)),
                linear(np.linspace(np.min(mus),np.max(mus),100))-
                    3*sigFunc(np.linspace(np.min(mus),np.max(mus),100)),alpha=.3)
#    ax.plot([bins[i],bins[i+1]],[linear(bins[i])+sigma,linear(bins[i+1])+sigma],color='k')
#    ax.plot([bins[i],bins[i+1]],[linear(bins[i])-sigma,linear(bins[i+1])-sigma],color='k')
    
#cb = fig.colorbar(m)

#ax.contour([mus,t0s],np.abs(t0s-linear(mus)))
print(lstsq[2]**2)
lstsq=scipy.stats.linregress(mus2,t0s)
print(lstsq[2]**2)
lstsq=scipy.stats.linregress(mus3,t0s)
print(lstsq[2]**2)
#ax.set_xscale("log", nonposx='clip')
#ax.set_yscale("log", nonposy='clip')
#ax.set_xlim((1e-3,ax.get_xlim()[-1]))
ax.set_xlabel('$\mu$ Effect Metric')
ax.set_ylabel('$\Delta t$')
plt.show()
# Out:
# 0.9398754541164549
# 0.00027864749882608697
# 0.00014581234795690127

# %%
fig=plt.figure()
ax=fig.gca()
ax.plot(t,-0.010509110575458868*t+0.15662983)
plt.show()

# %%
import matplotlib.cm as cm
import matplotlib.mlab as mlab

#Set up the 2D Gaussian:
delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)
sigma = 1.0
Z = mlab.bivariate_normal(X, Y, sigma, sigma, 0.0, 0.0)
#Get Z values for contours 1, 2, and 3 sigma away from peak:
z1 = mlab.bivariate_normal(0, 1 * sigma, sigma, sigma, 0.0, 0.0)
z2 = mlab.bivariate_normal(0, 2 * sigma, sigma, sigma, 0.0, 0.0)
z3 = mlab.bivariate_normal(0, 3 * sigma, sigma, sigma, 0.0, 0.0)
print(z1.shape,z2.shape,z3.shape)
plt.figure()
#plot Gaussian:
im = plt.imshow(Z, interpolation='bilinear', origin='lower',
                 extent=(-50,50,-50,50),cmap=cm.gray)
#Plot contours at whatever z values we want:
#CS = plt.contour(Z, [z1, z2, z3], origin='lower', extent=(-50,50,-50,50),colors='red')
plt.show()
# Out:
# ((), (), ())

# %%
nsim=100
modname ='snana-2004gv'
fig,ax=plt.subplots(nrows=2,ncols=2,sharex=True,sharey=False,figsize=(12,12))
fig2,ax2=plt.subplots(nrows=2,ncols=2,sharex=True,sharey=False,figsize=(12,12))
fig3,ax3=plt.subplots(nrows=2,ncols=2,sharex=True,sharey=False,figsize=(12,12))
#fig4,ax4=plt.subplots(nrows=2,ncols=2,sharex=True,sharey=False,figsize=(12,12))
origModel=sncosmo.Model(modname)
obsTime=np.linspace(-5,10,100)
zl=.5
row=0
col=0

for z in np.linspace(1,2,4):
    restTime=obsTime/(1+z)
    rs=[]
    slopes=[]
    constants=[]
    rs2=[]
    origModel.set(z=z)
    for i in range(nsim):
        model_i=sncosmo.Model(modname)
        model_i.set(z=z)
        time,dmag=simulation.microcaustic_field_to_curve(fitData[0],np.arange(0,50,1),zl,z)
        
        ml_effect = sncosmo.AchromaticMicrolensing(time+model_i._source._phase[0],dmag, magformat='add')
        model_i.add_effect(ml_effect, 'microlensing', 'rest')

        #print(model_i.get('t0'),origModel.get('t0'))
        
        t0=-obsTime[obsFlux==np.max(obsFlux)]
        model_i.set(t0=t0)
        origModel.set(t0=t0)
        obsFlux=model_i.bandflux('bessellb',obsTime,zp=25.,zpsys='ab')
        temp=Table([obsTime,obsFlux,.01*obsFlux,25.*np.ones(len(obsFlux)),
                    np.array(['ab' for i in range(len(obsFlux))]),
                   np.array(['bessellb' for i in range(len(obsFlux))])],
                   names=['time','flux','fluxerr','zp','zpsys','band'])
        res,fit=sncosmo.fit_lc(temp,origModel,['amplitude'])
        ml=obsFlux/fit.bandflux('bessellb',obsTime,zp=25.,zpsys='ab')
        
        #ml/=np.median(ml)
        lstsq=scipy.stats.linregress(obsTime,ml)
        s=lstsq[0]#(ml[-1]-ml[0])/15
        b=lstsq[1]#(s/2)*(ml[-1]+ml[0]-5)
        lin=s*obsTime+b
        
        #print(s,b)
        slopes.append(s)
        constants.append(b)
        #lstsq=scipy.stats.linregress(mus,t0s)
        #print(lstsq[2]**2)
        rs.append(np.sum((lin-ml)**2)/len(ml))
        rs2.append(lstsq[2]**2)
        #r=np.abs(scipy.stats.pearsonr(obsTime,ml)[0])
        #rs.append(r)
        #if np.sum((lin-ml)**2)>1000:
        #    fig2=plt.figure()
        #    ax2=fig2.gca()
        #    ax2.plot(obsTime,ml)
            #plt.show()
        #ax[row][col].plot(obsTime,ml)
    mean,sigma=scipy.stats.norm.fit(slopes)
    print('z='+str(np.round(z,2))+' slope:',mean,sigma)
    mean,sigma=scipy.stats.norm.fit(constants)
    print('z='+str(np.round(z,2))+' constants:',mean,sigma)
    ax[row][col].hist(rs2,normed=True,bins=nsim/5,label='Redshift '+str(np.round(z,2)))#,label='No Microlensing') 
    ax[row][col].legend()
    ax2[row][col].hist(slopes,normed=True,bins=nsim/5,label='Redshift '+str(np.round(z,2)))#,label='No Microlensing') )
    ax2[row][col].legend()
    ax3[row][col].hist(constants,normed=True,bins=nsim/5,label='Redshift '+str(np.round(z,2)))#,label='No Microlensing') )
    ax3[row][col].legend()
    #ax4[row][col].hist(rs2,normed=True,bins=nsim/5,label='Redshift '+str(np.round(z,2)))#,label='No Microlensing') )
    #ax4[row][col].legend()
    if col==1:
        col=0
        row+=1
    else:
        col+=1
fig.text(0.5, 0.02, '$\chi^2$ Statistic', ha='center',fontsize=16)
fig.text(0.04, .5, 'Probability Density', va='center', rotation='vertical',fontsize=16)
fig2.text(0.5, 0.02, '$\mu$ Slope', ha='center',fontsize=16)
fig2.text(0.04, .5, 'Probability Density', va='center', rotation='vertical',fontsize=16)
fig3.text(0.5, 0.02, '$\mu$ Y-Intercept', ha='center',fontsize=16)
fig3.text(0.04, .5, 'Probability Density', va='center', rotation='vertical',fontsize=16)

plt.show()
# Out:
# ('z=1.0 slope:', 0.0007572481528405311, 0.002781214974607861)
# ('z=1.0 constants:', 0.9984378691918235, 0.006281240285443985)
# ('z=1.33 slope:', 0.0003285308704050174, 0.0024126071837476133)
# ('z=1.33 constants:', 0.9994117446857385, 0.005892479533588372)
# ('z=1.67 slope:', -4.73847862760697e-05, 0.002415973981523643)
# ('z=1.67 constants:', 1.0003439120731203, 0.005875961747078692)
# ('z=2.0 slope:', 0.0005406152758249316, 0.0026094833350191584)
# ('z=2.0 constants:', 0.9989247859633669, 0.006060214581264979)

# %%
reload(simulation)
reload(sncosmo)
reload(fitting)

snType = 'Ia'
#bandlist = ['bessellb', 'bessellv', 'bessellr']
bandlist = ['F110W']
mF110W = np.array([25.0, 25.5, 25.8, 26.1, 26.4, 26.7, 27.0, 27.3, 27.6, 28.5])
SNR04  = np.array([25.8, 16.5, 12.6,  9.6,  7.3,  5.5,  4.2,  3.2,  2.4,  1.1])
stats=[]
deltas=[]
ia_all_lcs1=[]
ia_all_lcs2=[]
ia_all_lcs3=[]
all_orig=[]
mlList=[]
mlMeasuredList=[]
nsim=100
#times=np.append(np.linspace(0,20,15),np.linspace(73,88,15))
z=1.6
for i in range(nsim):
    modname= sncosmo.SALT2Source(modeldir='salt2-extended')
    print(i)
    go=True
    while go:
        lcs = simulation.createMultiplyImagedSN(
            modname, snType, z,z_lens=.53, bands=bandlist,#timeArr=times,
            zp=[26.8], cadence=5., epochs=30.,skynoiseRange=(.001,.005),gain=70. , time_delays=[10., 78.],
            magnifications=[15,10], objectName='BELLS J0830+5116--Type Ia', telescopename='HST',
            microlensing_type='AchromaticMicrolensing',scatter=True,av_host=None,
            microlensing_params=fitData[0],minsnr=5.0,snrFunc=interp1d(mF110W,SNR04,'quadratic'))
        if lcs is not None:
            keep=0
            for k in lcs.images.keys():
                lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['time']<{'S1':10,'S2':78}[k]+50]
                lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['time']>{'S1':10,'S2':78}[k]-25]
                if len(lcs.images[k].table)==0:
                    keep+=1
            if keep==0:
                go=False
    all_orig.append(lcs)
    
    #lcs.plot_object(showfig=True,savefig=True,showmodel=True)
    #plt.show()
    
    
    #mods=['2006ep','2007Y','2005hm','2006jo','2007nc']
    modname=[modname]#['snana-'+m for m in mods]
    
    '''
    pre=fitting.fit_data(lcs, snType='Ia', models=modname,bands=bandlist,
                                    params=['x0','x1','t0','c'],
                                    constants={'z':z},
                                    bounds={'t0':(-15,15),'x1':(-2,2),'c':(0,1)},
                                    combined_or_separate='separate',showPlots=False,microlensing=None)
    

    #for k in lcs_tdfit.images.keys():
    #    print(lcs_tdfit.images[k].fits.res.logz)
    ia_all_lcs1.append({'S2':pre.images['S2'].fits.model.get('t0'),'S1':pre.images['S1'].fits.model.get('t0')})
    '''
    
    lcs_tdfit=fitting.fit_data(lcs, snType='Ia', models=modname,bands=bandlist,
                                    params=['x0','x1','t0','c'],
                                    constants={'z':z},#t0_guess={'S1':10,'S2':78},
                                    bounds={'t0':(-15,15),'x1':(-2,2),'c':(0,1)},
                                    combined_or_separate='separate',showPlots=False,microlensing='achromatic')
    
    ia_all_lcs1.append({'S2':lcs.images['S2'].simMeta['microlensing'],'S1':lcs.images['S1'].simMeta['microlensing']})
    ia_all_lcs2.append({'S2':(lcs_tdfit.images['S2'].fits.final_errs['t0'],lcs_tdfit.images['S2'].fits.final_errs['micro']),
                        'S1':(lcs_tdfit.images['S1'].fits.final_errs['t0'],lcs_tdfit.images['S1'].fits.final_errs['micro'])})
    ia_all_lcs3.append({'S2':lcs_tdfit.images['S2'].fits.model.get('t0'),'S1':lcs_tdfit.images['S1'].fits.model.get('t0')})
    #print(all_lcs1,all_lcs2,lcs_tdfit.images['S2'].fits.model.get('t0')-lcs_tdfit.images['S1'].fits.model.get('t0'))
    '''
    mlDict=dict([])
    mlMeasured=dict([])
    for k in lcs.images.keys():
        t=np.arange(-5,10.001,.01)
        
        mlDiff=lcs_tdfit.images[k].fits.model.get('amplitude')/(lcs.model.get('amplitude')*lcs.images[k].simMeta['mu'])
        #tempTime=lcs.images[k].table['time']
        #tempTime=tempTime[tempTime>=-15]
        #tempTime=tempTime[tempTime<=40]
        fig=plt.figure()
        ax=fig.gca()
        ml=(10**(-.4*lcs.images[k].simMeta['microlensing_params'](t/(1+z))),lcs.model.get('amplitude')*lcs.images[k].simMeta['mu'])
        mlDict[k]=ml
        mlMeasured[k]=(lcs_tdfit.images[k].fits.model._effects[0],lcs_tdfit.images[k].fits.model.get('amplitude'))
        ax.plot(t,ml[0]/mlDiff,label='Actual')
        ax.plot(t,mlMeasured[k][0].mu(t),label='Measured')
        #ax.set_xlim((-10,10))
        #ax.set_ylim((.95,1.05))
        ax.legend()
        plt.show()
        print(lcs_tdfit.images[k].fits.model.get('t0'),(ml[0][-1]-ml[0][0])/(15*mlDiff),lcs_tdfit.images[k].fits.model.get('microlensingA'))
        #print((ml[np.abs(t-5)<.001]/mlDiff-ml[np.abs(t+5)<.001]/mlDiff)/(5.+5.))
    
    mlList.append(mlDict)
    mlMeasuredList.append(mlMeasured)
    
    for k in lcs_tdfit.images.keys():
        t=np.arange(-5,10.001,.01)+{'S1':10,'S2':78}[k]
        
        f=lcs_tdfit.images[k].fits.model.bandflux('F110W',t,zp=26.8,zpsys='AB')
        fb= lcs_tdfit.images[k].fits.model.bandflux('bessellb',t,zp=25.0,zpsys='AB')
        print('micro',lcs_tdfit.images[k].fits.model.get('t0'),lcs_tdfit.images[k].fits.res.logz)
        fig=plt.figure()
        ax=fig.gca()
    #ax.plot(t,f,label='Microlensing')
        lcs_tdfit.images[k].fits.model._effects=[]
        f=lcs_tdfit.images[k].fits.model.bandflux('F110W',t,zp=26.8,zpsys='AB')
        fb= lcs_tdfit.images[k].fits.model.bandflux('bessellb',t,zp=25.0,zpsys='AB')
        #print('no micro',t[f==np.max(f)],t[fb==np.max(fb)],lcs_tdfit.images[k].fits.model.get('t0'))
        ax.plot(t,f,label='Microlensing Removed')
        f2=pre.images[k].fits.model.bandflux('F110W',t,zp=26.8,zpsys='AB')
        #fb= pre.images[k].fits.model.bandflux('bessellb',t,zp=25.0,zpsys='AB')
        f3=lcs.images[k].simMeta['model'].bandflux('F110W',t,zp=26.8,zpsys='AB')
        ax.plot(t,f3,label='actual ML')
        #print(t[f==np.max(f)],t[fb==np.max(fb)],pre.images[k].fits.model.get('t0'))
        #print('micro',t[f3==np.max(f3)])
        ax.plot(t,np.max(f)/np.max(f2)*f2,label='No Microlensing')
        ax.scatter(lcs.images[k].table['time'],lcs.images[k].table['flux'])
        #ax.plot(lcs.images[k].simMeta['model']._source._phase,lcs.images[k].simMeta['model'].bandflux('F110W',lcs.images[k].simMeta['model']._source._phase,zp=26.8,zpsys='AB'),label='actual')
        lcs.images[k].simMeta['model']._effects=[]
        f3=lcs.images[k].simMeta['model'].bandflux('F110W',t,zp=26.8,zpsys='AB')
        print('no micro',pre.images[k].fits.model.get('t0'),pre.images[k].fits.res.logz)
        ax.plot(t,np.max(f)/np.max(f3)*f3,'--',label='actual no ML')#
        ax.set_xlim((t[0],t[-1]))
        ax.legend()
        plt.show()
    '''   
    
#lcs_tdfit=fitting.fit_data(lcs, snType='Ib', models=[modname],bands=bandlist,
#                                params=['amplitude','t0','hostebv'],
#                                constants={'z':1.33,'hostr_v':3.1},t0_guess={'S1':10,'S2':78},
#                                bounds={'t0':(-.001,.001),'hostebv':(0,.2)},
#                                effect_frames=['rest'],effect_names=['host'],dust='CCM89Dust',
#                                combined_or_separate='separate',showPlots=True)
# Out:
# 0
# <type 'numpy.ndarray'>
# (77.06516657033089, 77.3465271636717)
# <type 'numpy.ndarray'>
# (8.19505385416965, 8.616592340315247)
# 1
# <type 'numpy.ndarray'>
# (77.38675055766255, 77.53923278242367)
# <type 'numpy.ndarray'>
# (8.001849007367053, 8.456971587170017)
# 2
# <type 'numpy.ndarray'>
# (75.89054114862837, 76.00612920653818)
# <type 'numpy.ndarray'>
# (7.532257070673679, 8.121288545893648)
# 3
# <type 'numpy.ndarray'>
# (77.45169555396883, 77.50846418120621)
# <type 'numpy.ndarray'>
# (8.971748887804951, 9.23280033942655)
# 4
# <type 'numpy.ndarray'>
# (75.54930880390248, 76.0861495902882)
# <type 'numpy.ndarray'>
# (8.351309154908392, 9.06343600601716)
# 5
# <type 'numpy.ndarray'>
# (77.29196020240425, 77.33267307265083)
# <type 'numpy.ndarray'>
# (9.094341463964394, 9.31185822339304)
# 6
# <type 'numpy.ndarray'>
# (76.35605826894451, 76.48939859605512)
# <type 'numpy.ndarray'>
# (8.354420922788812, 8.95335064860603)
# 7
# <type 'numpy.ndarray'>
# ...

# %%
temp=open('ia_temp.dat','rb')
dat=[]
for line in temp.readlines():
    if line[0]=='(':
        print(float(line[line.rfind(',')+1:-2]))
        dat=np.append(dat,np.abs(float(line[1:line.rfind(',')])-float(line[line.rfind(',')+1:-2])))
# Out:
# 77.3465271637
# 8.61659234032
# 77.5392327824
# 8.45697158717
# 76.0061292065
# 8.12128854589
# 77.5084641812
# 9.23280033943
# 76.0861495903
# 9.06343600602
# 77.3326730727
# 9.31185822339
# 76.4893985961
# 8.95335064861
# 77.3850526715
# 8.80535863088
# 76.9906270482
# 8.69486902045
# 76.6411084309
# 8.12939470508
# 76.5335512618
# 7.84866873882
# 76.2064193317
# 8.66416298836
# 77.0354420972
# 9.16556815595
# 76.6684051513
# 8.79406810972
# 77.8562294186
# 9.60329204626
# 77.3104010662
# 8.97558806483
# 76.8802027561
# 8.54426716064
# 77.0505398049
# 6.26200759043
# 77.0877484564
# 8.5119976723
# 77.0430896604
# 9.60036889301
# 76.7426568021
# 11.6330956499
# 76.7283920537
# 8.75708329788
# 78.2725531166
# 9.03219025485
# 77.932897501
# 10.4900577201
# 77.1595854965
# 9.2043931703
# 76.6034500058
# 8.81798620445
# 76.8513056985
# 10.307755773
# 79.5274477734
# 9.1275358937
# 76.3519039163
# 8.51732090793
# 77.1301630724
# 9.38932800406
# 76.8649196692
# 9.35816521186
# ...

# %%
fig=plt.figure()
ax=fig.gca()
t=np.linspace(-5,1,500)/(1+1.6)
correct={'S1':10,'S2':78}
all1=[]
all2=[]
N=20
allx=[]
for k in ['S2','S1']:
    #print([x[k][1] for x in ia_all_lcs2])
    t0=np.array([x[k] for x in ia_all_lcs3])
    ml=np.array([x[k] for x in ia_all_lcs1])
    errNoml=np.array([x[k][0] for x in ia_all_lcs2])
    errMl=np.array([np.sqrt(ia_all_lcs2[i][k][0]**2+9*ia_all_lcs2[i][k][1]**2+9*dat[i]**2) for i in range(len(ia_all_lcs2))])
    slopes=[np.sum(np.abs(np.gradient(x.mu(t)))) for x in ml]
    errNoml=errNoml[np.abs(t0-correct[k])<=4]
    errMl=errMl[np.abs(t0-correct[k])<=4]
    t0=t0[np.abs(t0-correct[k])<=4]
    if k=='S2':
        #ax.scatter(t0-correct[k],np.abs(t0-correct[k])/(errNoml),color='r',label='Model Uncertainty')
        #ax.scatter(t0-correct[k],np.abs(t0-correct[k])/(errMl),color='b',label='Model+ML Uncertainty')
        ax.scatter(np.abs(t0-correct[k]),(np.abs(t0-correct[k]))/(errNoml),color='r',label='Model Uncertainty')
        ax.scatter(np.abs(t0-correct[k]),(np.abs(t0-correct[k]))/(errMl),color='b',label='Model+ML Uncertainty')
    else:
        ax.scatter(np.abs(t0-correct[k]),(np.abs(t0-correct[k]))/(errNoml),color='r')
        ax.scatter(np.abs(t0-correct[k]),(np.abs(t0-correct[k]))/(errMl),color='b')
        #ax.scatter(t0-correct[k],np.abs(t0-correct[k])/(errNoml),color='r')
        #ax.scatter(t0-correct[k],np.abs(t0-correct[k])/(errMl),color='b')
    all1=np.append(all1,(np.abs(t0-correct[k]))/(errNoml))
    all2=np.append(all2,(np.abs(t0-correct[k]))/(errMl))
    allx=np.append(allx,np.abs(t0-correct[k]))
    #for i in range(len(ia_all_lcs2)):
    #    print(np.abs(t0[i]-correct[k]),ia_all_lcs2[i][k][0],ia_all_lcs2[i][k][1],dat[i])
    #print(3*errMl)
#all1=all1[allx<=4]
#all2=all2[allx<=4]
#allx=allx[allx<=4]
#for s in [1,2,3]:
#    print(len(all1[all1<=s]))/float(len(allx)),(len(all2[all2<=s]))/float(len(allx))
ind=np.argsort(allx)


ax_divider = make_axes_locatable(ax)
ax_ml = ax_divider.append_axes("right", size="50%", pad=.4)
n,bins,_=ax_ml.hist(all1,bins=25,orientation='horizontal',alpha=.5,color='r',normed=True)
y = mlab.normpdf(bins, np.mean(all1), np.std(all1))
y2 = mlab.normpdf(-bins, np.mean(all1), np.std(all1))
#ax_ml.plot(np.abs(y)+np.abs(y2),bins,color='r')
n,bins,_=ax_ml.hist(all2,bins=25,orientation='horizontal',alpha=.5,color='b',normed=True)
y = mlab.normpdf(bins, np.mean(all2), np.std(all2))
y2 = mlab.normpdf(-bins, np.mean(all2), np.std(all2))
#ax_ml.plot(np.abs(y)+np.abs(y2),bins,color='b')
y = mlab.normpdf(bins, np.mean(all2), 1)
y2 = mlab.normpdf(-bins, np.mean(all2), 1)
#ax_ml.plot(np.abs(y)+np.abs(y2),bins,color='g')
ax.set_xlabel('$\Delta t$ (Days)',fontsize=14)
ax.set_ylabel(r'$\Delta t/\sigma$',fontsize=14)
#ax.set_xlim((0,4))
ax.set_ylim((0,12))
ax.plot(ax.get_xlim(),[3,3],'g--',label='$3\sigma$')
#ax.plot(ax.get_xlim(),[2,2],'g--')
#ax.plot(ax.get_xlim(),[1,1],'g--')
ax.legend()

plt.show()
plt.close()

# %%
fig=plt.figure()
ax=fig.gca()
from scipy.signal import savgol_filter as smooth

values, base = np.histogram(all2, bins=25)
func1=interp1d(base[:-1],np.cumsum(values)/float(len(allx)),'quadratic')
x=np.linspace(base[0],base[-2],1000)
ax.plot(x,smooth(func1(x),501,2),'b-.',linewidth=2,label='Model+ML Uncertainty')
values, base = np.histogram(all1, bins=25)
func2=interp1d(base[:-1],np.cumsum(values)/float(len(allx)),'quadratic')
x=np.linspace(base[0],base[-2],1000)
ax.plot(x,func2(x),'r--',linewidth=2,label='Model Uncertainty')
rand=np.abs(np.random.randn(10000))
values, base = np.histogram(rand, bins=100)
func3=interp1d(base[:-1],np.cumsum(values)/10000.,'quadratic')
ax.plot(base[:-1],np.cumsum(values)/10000.,'g-',linewidth=2,label="Gaussian Uncertainty")

#ax.plot([1,1],[0,1],'r--')
#ax.plot([2,2],[0,1],'r--')
#ax.plot([3,3],[0,1],'r--')
ax.legend()
ax.set_xlabel('$n\sigma$',fontsize=14)
ax.set_ylabel('Cumulative Density',fontsize=14)
ax.set_xlim((0,3.5))

plt.show()

# %%
reload(simulation)
reload(sncosmo)
reload(fitting)
modname ='snana-2004gv'#
snType = 'Ib'
#bandlist = ['bessellb', 'bessellv', 'bessellr']
bandlist = ['F110W']
mF110W = np.array([25.0, 25.5, 25.8, 26.1, 26.4, 26.7, 27.0, 27.3, 27.6, 28.5])
SNR04  = np.array([25.8, 16.5, 12.6,  9.6,  7.3,  5.5,  4.2,  3.2,  2.4,  1.1])
stats=[]
deltas=[]
all_lcs1=[]
all_lcs2=[]
all_lcs3=[]
all_orig=[]
mlList=[]
mlMeasuredList=[]
nsim=1000
times=np.append(np.linspace(0,20,15),np.linspace(73,88,15))
z=1.6
for i in range(nsim):
    modname ='snana-2004gv'
    print(i)
    go=True
    while go:
        lcs = simulation.createMultiplyImagedSN(
            modname, snType, z,z_lens=.53, bands=bandlist,#timeArr=times,
            zp=[26.8], cadence=5., epochs=30.,skynoiseRange=(.001,.005),gain=70. , time_delays=[10., 78.],
            magnifications=[30,20], objectName='BELLS J0830+5116--Type Ia', telescopename='HST',
            microlensing_type='AchromaticMicrolensing',scatter=True,av_host=None,
            microlensing_params=fitData[0],minsnr=5.0,snrFunc=interp1d(mF110W,SNR04,'quadratic'))
        if lcs is not None:
            keep=0
            for k in lcs.images.keys():
                lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['time']<{'S1':10,'S2':78}[k]+50]
                lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['time']>{'S1':10,'S2':78}[k]-25]
                if len(lcs.images[k].table)==0:
                    keep+=1
            if keep==0:
                go=False
    all_orig.append(lcs)
    
    #lcs.plot_object(showfig=True,savefig=True,showmodel=True)
    #plt.show()
    
    
    mods=['2006ep','2007Y','2005hm','2006jo','2007nc']
    modname=[modname]#['snana-'+m for m in mods]
    
    
    pre=fitting.fit_data(lcs, snType='Ib', models=modname,bands=bandlist,
                                    params=['amplitude','t0'],
                                    constants={'z':z},
                                    bounds={'t0':(-10,10)},#t0_guess={'S1':10,'S2':78},
                                    combined_or_separate='separate',showPlots=False,microlensing=None)
    

    #for k in lcs_tdfit.images.keys():
    #    print(lcs_tdfit.images[k].fits.res.logz)
    all_lcs1.append({'S2':pre.images['S2'].fits.model.get('t0'),'S1':pre.images['S1'].fits.model.get('t0')})
    
    
    lcs_tdfit=fitting.fit_data(lcs, snType='Ib', models=modname,bands=bandlist,
                                    params=['amplitude','t0'],
                                    constants={'z':z},#t0_guess={'S1':10,'S2':78},
                                    bounds={'t0':(-10,10)},
                                    combined_or_separate='separate',showPlots=False,microlensing='achromatic')
    yes_res=dict([])
    for k in ['S1','S2']:
        if k=='S1':
            t=np.arange(-5,25,.01)
        else:
            t=np.arange(63,93,.01)
        
        f_yes=lcs_tdfit.images[k].fits.model.bandflux('F110W',t,zp=26.8,zpsys='AB')
        fb_yes= lcs_tdfit.images[k].fits.model.bandflux('bessellb',t,zp=25.0,zpsys='AB')
        yes_res[k]=t[f_yes==np.max(f_yes)]

    #all_lcs2.append({'S2':lcs_tdfit.images['S2'].fits.model.effects[0],'S1':lcs_tdfit.images['S1'].fits.model.effects[0]})
    all_lcs3.append({'S2':lcs_tdfit.images['S2'].fits.model.get('t0'),'S1':lcs_tdfit.images['S1'].fits.model.get('t0')})
    #print(all_lcs1,all_lcs2,lcs_tdfit.images['S2'].fits.model.get('t0')-lcs_tdfit.images['S1'].fits.model.get('t0'))
    '''
    mlDict=dict([])
    mlMeasured=dict([])
    for k in lcs.images.keys():
        t=np.arange(-5,10.001,.01)
        
        mlDiff=lcs_tdfit.images[k].fits.model.get('amplitude')/(lcs.model.get('amplitude')*lcs.images[k].simMeta['mu'])
        #tempTime=lcs.images[k].table['time']
        #tempTime=tempTime[tempTime>=-15]
        #tempTime=tempTime[tempTime<=40]
        fig=plt.figure()
        ax=fig.gca()
        ml=(10**(-.4*lcs.images[k].simMeta['microlensing_params'](t/(1+z))),lcs.model.get('amplitude')*lcs.images[k].simMeta['mu'])
        mlDict[k]=ml
        mlMeasured[k]=(lcs_tdfit.images[k].fits.model._effects[0],lcs_tdfit.images[k].fits.model.get('amplitude'))
        ax.plot(t,ml[0]/mlDiff,label='Actual')
        ax.plot(t,mlMeasured[k][0].mu(t),label='Measured')
        #ax.set_xlim((-10,10))
        #ax.set_ylim((.95,1.05))
        ax.legend()
        plt.show()
        print(lcs_tdfit.images[k].fits.model.get('t0'),(ml[0][-1]-ml[0][0])/(15*mlDiff),lcs_tdfit.images[k].fits.model.get('microlensingA'))
        #print((ml[np.abs(t-5)<.001]/mlDiff-ml[np.abs(t+5)<.001]/mlDiff)/(5.+5.))
    
    mlList.append(mlDict)
    mlMeasuredList.append(mlMeasured)
    
    for k in lcs_tdfit.images.keys():
        t=np.arange(-5,10.001,.01)+{'S1':10,'S2':78}[k]
        
        f=lcs_tdfit.images[k].fits.model.bandflux('F110W',t,zp=26.8,zpsys='AB')
        fb= lcs_tdfit.images[k].fits.model.bandflux('bessellb',t,zp=25.0,zpsys='AB')
        print('micro',lcs_tdfit.images[k].fits.model.get('t0'),lcs_tdfit.images[k].fits.res.logz)
        fig=plt.figure()
        ax=fig.gca()
    #ax.plot(t,f,label='Microlensing')
        lcs_tdfit.images[k].fits.model._effects=[]
        f=lcs_tdfit.images[k].fits.model.bandflux('F110W',t,zp=26.8,zpsys='AB')
        fb= lcs_tdfit.images[k].fits.model.bandflux('bessellb',t,zp=25.0,zpsys='AB')
        #print('no micro',t[f==np.max(f)],t[fb==np.max(fb)],lcs_tdfit.images[k].fits.model.get('t0'))
        ax.plot(t,f,label='Microlensing Removed')
        f2=pre.images[k].fits.model.bandflux('F110W',t,zp=26.8,zpsys='AB')
        #fb= pre.images[k].fits.model.bandflux('bessellb',t,zp=25.0,zpsys='AB')
        f3=lcs.images[k].simMeta['model'].bandflux('F110W',t,zp=26.8,zpsys='AB')
        ax.plot(t,f3,label='actual ML')
        #print(t[f==np.max(f)],t[fb==np.max(fb)],pre.images[k].fits.model.get('t0'))
        #print('micro',t[f3==np.max(f3)])
        ax.plot(t,np.max(f)/np.max(f2)*f2,label='No Microlensing')
        ax.scatter(lcs.images[k].table['time'],lcs.images[k].table['flux'])
        #ax.plot(lcs.images[k].simMeta['model']._source._phase,lcs.images[k].simMeta['model'].bandflux('F110W',lcs.images[k].simMeta['model']._source._phase,zp=26.8,zpsys='AB'),label='actual')
        lcs.images[k].simMeta['model']._effects=[]
        f3=lcs.images[k].simMeta['model'].bandflux('F110W',t,zp=26.8,zpsys='AB')
        print('no micro',pre.images[k].fits.model.get('t0'),pre.images[k].fits.res.logz)
        ax.plot(t,np.max(f)/np.max(f3)*f3,'--',label='actual no ML')#
        ax.set_xlim((t[0],t[-1]))
        ax.legend()
        plt.show()
    '''   
    
#lcs_tdfit=fitting.fit_data(lcs, snType='Ib', models=[modname],bands=bandlist,
#                                params=['amplitude','t0','hostebv'],
#                                constants={'z':1.33,'hostr_v':3.1},t0_guess={'S1':10,'S2':78},
#                                bounds={'t0':(-.001,.001),'hostebv':(0,.2)},
#                                effect_frames=['rest'],effect_names=['host'],dust='CCM89Dust',
#                                combined_or_separate='separate',showPlots=True)

# %%
noScatter1=deepcopy(all_lcs1)
noScatter2=deepcopy(all_lcs2)

# %%
scatter1=deepcopy(ia_all_lcs1)
scatter2=deepcopy(all_lcs2)
#scatter2=[x[0] for x in scatter2]
scatter3=deepcopy(ia_all_lcs3)
scatterML=deepcopy(mlList)
scatterMLmeasured=deepcopy(mlMeasuredList)

# %%
fig=plt.figure()
ax=fig.gca()
t0=1.
pks={'S2':78,'S1':10}
syms={'S1':'*','S2':'^'}
allx=[]
ally=[]
for k in ['S1','S2']:
    tempx=np.array([x[k] for x in scatter3])
    mu,sigma=scipy.stats.norm.fit(tempx)
    tempy=np.abs([(x[k][0][np.abs(t-t0)<.001]-x[k][0][np.abs(t+t0)<.001])/(2*t0) for x in scatterML])
    inds1=np.where(tempy>=0)[0]
    
    ax.scatter(tempy[inds1],np.abs(tempx-pks[k])[inds1],
               label=k+r' $\Delta t\leq1\sigma$',marker=syms[k],color='b')
    ally=np.append(ally,np.abs(tempx[inds1]-pks[k]))
    allx=np.append(allx,tempy[inds1])
    #ind1=np.where(t>=-t0)[0][0]
    #ind2=np.where(t<=t0)[0][-1]
    #ax.scatter(np.abs(np.array(scatter3)-68),np.array([np.max(x[k][ind1:ind2+1]) for x in scatterML]))
    inds=np.where(np.abs(tempx[inds1]-pks[k])>sigma)[0]
    ax.scatter(np.abs([(x[k][0][np.abs(t-t0)<.001]-x[k][0][np.abs(t+t0)<.001])/(2*t0) for x in np.array(scatterML)[inds1][inds]]),np.abs(tempx[inds1][inds]-pks[k]),
               color='r',label=k+r' $\Delta t>1\sigma$',marker=syms[k])
    #ax.scatter(np.abs(np.array(scatter3)[inds]-68),np.array([np.max(x[k][ind1:ind2+1]) for x in np.array(scatterML)[inds]]),color='r')

lstsq=scipy.stats.linregress(allx,ally)
m=lstsq[0]
c=lstsq[1]
R=lstsq[2]
p=lstsq[3]
print(m,c,R)
ax.set_xlim([0,1.1*np.max(np.abs([(x[k][0][np.abs(t-t0)<.001]-x[k][0][np.abs(t+t0)<.001])/(2*t0) for x in scatterML]))])
x=np.linspace(0,ax.get_xlim()[1],100)
ax.plot(x,m*x+c,color='k',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
ax.set_ylabel('$\Delta t$')
ax.set_xlabel(r'$\mu-\rm{slope}$')
#ax.annotate('$R^2='+str(np.round(R**2,2))+'$',fontsize=15,xy=(.3,.9),xycoords='axes fraction')
ax.set_title('Time Delay Measurement vs. $\mu-$lensing Slope Near Peak')
ax.legend(loc='upper left',fontsize=8)
plt.show()

fig=plt.figure()
ax=fig.gca()
pks={'S2':78,'S1':10}
syms={'S1':'*','S2':'^'}
allx=[]
ally=[]
for k in ['S1','S2']:
    tempx=np.array([x[k] for x in scatter3])
    mean,sigma=scipy.stats.norm.fit(tempx)
    mu=np.array([x[k][1]*x[k][0].mu(t) for x in scatterMLmeasured])
    tempy=np.abs([(x[np.abs(t-t0)<.001]-x[np.abs(t+t0)<.001])/(2*t0) for x in mu])
    inds1=np.where(tempy>=0)[0]
    
    ax.scatter(tempy[inds1],np.abs(tempx-pks[k])[inds1],
               label=k+r' $\Delta t\leq1\sigma$',marker=syms[k],color='b')
    ally=np.append(ally,np.abs(tempx[inds1]-pks[k]))
    allx=np.append(allx,tempy[inds1])
    #ind1=np.where(t>=-t0)[0][0]
    #ind2=np.where(t<=t0)[0][-1]
    #ax.scatter(np.abs(np.array(scatter3)-68),np.array([np.max(x[k][ind1:ind2+1]) for x in scatterML]))
    inds=np.where(np.abs(tempx[inds1]-pks[k])>sigma)[0]
    ax.scatter(np.abs([(x[np.abs(t-t0)<.001]-x[np.abs(t+t0)<.001])/(2*t0) for x in np.array(mu)[inds1][inds]]),np.abs(tempx[inds1][inds]-pks[k]),
               color='r',label=k+r' $\Delta t>1\sigma$',marker=syms[k])
    #ax.scatter(np.abs(np.array(scatter3)[inds]-68),np.array([np.max(x[k][ind1:ind2+1]) for x in np.array(scatterML)[inds]]),color='r')

lstsq=scipy.stats.linregress(allx,ally)
m=lstsq[0]
c=lstsq[1]
R=lstsq[2]
p=lstsq[3]
print(m,c,R)
ax.set_xlim([0,1.1*np.max(np.abs([(x[np.abs(t-t0)<.001]-x[np.abs(t+t0)<.001])/(2*t0) for x in mu]))])
x=np.linspace(0,ax.get_xlim()[1],100)
ax.plot(x,m*x+c,color='k',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
ax.set_ylabel('$\Delta t$')
ax.set_xlabel(r'$\mu-\rm{slope}$')
#ax.annotate('$R^2='+str(np.round(R**2,2))+'$',fontsize=15,xy=(.3,.9),xycoords='axes fraction')
ax.set_title('Time Delay Measurement vs. $\mu-$lensing Slope Near Peak')
ax.legend(loc='upper left',fontsize=8)
plt.show()


fig=plt.figure()
ax=fig.gca()

x_lower=np.inf
x_upper=-np.inf
y_lower=np.inf
y_upper=-np.inf
all1=[]
all2=[]
for k in ['S1','S2']:
    slope1=np.abs([x[k][1]*(x[k][0][np.abs(t-t0)<.001]-x[k][0][np.abs(t+t0)<.001])/(2*t0) for x in scatterML])
    mu=np.array([x[k][0].mu(t)*x[k][1] for x in scatterMLmeasured])
    slope2=np.abs([(x[np.abs(t-t0)<.001]-x[np.abs(t+t0)<.001])/(2*t0) for x in mu])
    ax.scatter(slope1,slope2,marker=syms[k])
    all1=np.append(all1,slope1)
    all2=np.append(all2,slope2)
    x_lower=min(np.min(slope1),x_lower)
    x_upper=max(np.max(slope1),x_upper)
    y_lower=min(np.min(slope2),y_lower)
    y_upper=max(np.max(slope2),y_upper)
    
lstsq=scipy.stats.linregress(all1,all2)
m=lstsq[0]
c=lstsq[1]
R=lstsq[2]
p=lstsq[3]
print(m)
ax.set_xlim((.9*x_lower,1.1*x_upper))
ax.set_ylim((.9*y_lower,1.1*y_upper))
x=np.linspace(0,ax.get_xlim()[1],100)
ax.loglog(x,m*x+c,color='k',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
ax.legend()
plt.show()
'''
for i in range(len(scatterML)):
    for k in ['S1','S2']:
        mu=scatterMLmeasured[i][k][0].mu(t)
        fig=plt.figure()
        ax=fig.gca()
        ax.plot(t,scatterML[i][k])
        ax.plot(t,mu)
        ax.set_xlim((-5,5))
        plt.show()
'''

# %%
t=np.arange(-15,15,.01)
fig=plt.figure()
ax=fig.gca()
t0=-5
t1=10
pks={'S2':78,'S1':10}
syms={'S1':'*','S2':'^'}
allx=[]
ally=[]
for k in ['S1','S2']:
    tempx=np.array([x[k] for x in scatter3])
    mu,sigma=scipy.stats.norm.fit(tempx)
    ind1=np.where(np.abs(t-t0)<.001)[0][0]
    ind2=np.where(np.abs(t-t1)<.001)[0][0]
    tempy=np.array([np.sum(np.abs(np.gradient(x[k][0][ind1:ind2+1]))) for x in scatterML])
    inds1=np.where(tempy>=0)[0]
    
    ax.scatter(tempy[inds1],np.abs(tempx-pks[k])[inds1],
               label=k+r' $\Delta t\leq1\sigma$',marker=syms[k],color='b')
    ally=np.append(ally,np.abs(tempx[inds1]-pks[k]))
    allx=np.append(allx,tempy[inds1])
    #ind1=np.where(t>=-t0)[0][0]
    #ind2=np.where(t<=t0)[0][-1]
    #ax.scatter(np.abs(np.array(scatter3)-68),np.array([np.max(x[k][ind1:ind2+1]) for x in scatterML]))
    inds=np.where(np.abs(tempx[inds1]-pks[k])>sigma)[0]
    ax.scatter(np.array([np.sum(np.abs(np.gradient(x[k][0][ind1:ind2+1]))) for x in np.array(scatterML)[inds1][inds]]),np.abs(tempx[inds1][inds]-pks[k]),
               color='r',label=k+r' $\Delta t>1\sigma$',marker=syms[k])
    #ax.scatter(np.abs(np.array(scatter3)[inds]-68),np.array([np.max(x[k][ind1:ind2+1]) for x in np.array(scatterML)[inds]]),color='r')

#lstsq=scipy.stats.linregress(allx[allx>.03],ally[allx>.03])
#m=lstsq[0]
#c=lstsq[1]
#R=lstsq[2]
#p=lstsq[3]
ax.set_xlim([0,1.1*np.max(np.array([np.sum(np.abs(np.gradient(x[k][0][ind1:ind2+1]))) for x in scatterML]))])
ax.set_ylim([0,np.max(ally)])
x=np.linspace(0,ax.get_xlim()[1],100)
#ax.plot(x,m*x+c,color='r',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
lstsq=scipy.stats.linregress(allx,ally)#[allx<=.03],ally[allx<=.03])
m=lstsq[0]
c=lstsq[1]
R=lstsq[2]
p=lstsq[3]

linear=interp1d(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100),m*np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)+c)
ax.plot(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100),linear(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)))
#from scipy.interpolate import Rbf
z=np.abs(ally-linear(allx))
sort=np.argsort(allx)
allx=allx[sort]
ally=ally[sort]

allsigs=[0]
allVals=[0]
dmu=10
for i in np.arange(0,len(allx),dmu):
    mean,sigma=scipy.stats.norm.fit(z[i:min(i+dmu,len(allx))])
    allsigs.append(sigma)
    allVals.append(allx[min(i+dmu,len(allx)-1)])
sigFunc=interp1d(allVals,allsigs,fill_value='extrapolate',bounds_error=False)
ax.fill_between(np.linspace(np.min(allx),np.max(allx),100),
                linear(np.linspace(np.min(allx),np.max(allx),100))+
                    3*sigFunc(np.linspace(np.min(allx),np.max(allx),100)),
                linear(np.linspace(np.min(allx),np.max(allx),100))-
                    3*sigFunc(np.linspace(np.min(allx),np.max(allx),100)),alpha=.3)
ax.plot(x,m*x+c,color='k',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
ax.set_ylabel('$\Delta t$')
ax.set_xlabel(r'$\mu-\rm{slope}$')
#ax.annotate('$R^2='+str(np.round(R**2,2))+'$',fontsize=15,xy=(.3,.9),xycoords='axes fraction')
ax.set_title('Time Delay Measurement vs. $\mu-$lensing Slope Near Peak')
ax.legend(loc='upper left',fontsize=8)
plt.show()

fig=plt.figure()
ax=fig.gca()
#t0=-5
#t1=10
pks={'S2':78,'S1':10}
syms={'S1':'*','S2':'^'}
allx=[]
ally=[]
for k in ['S1','S2']:
    tempx=np.array([x[k] for x in scatter3])
    mu,sigma=scipy.stats.norm.fit(tempx)
    ind1=np.where(np.abs(t-t0)<.001)[0][0]
    ind2=np.where(np.abs(t-t1)<.001)[0][0]
    tempy=np.array([np.sum(np.abs(np.gradient(x[k][0][ind1:ind2+1]))) for x in scatterML])
    inds1=np.where(tempy>=0)[0]
    
    ax.scatter(tempy[inds1],np.abs(tempx-pks[k])[inds1],
               label=k+r' $\Delta t\leq1\sigma$',marker=syms[k],color='b')
    ally=np.append(ally,np.abs(tempx[inds1]-pks[k]))
    allx=np.append(allx,tempy[inds1])
    #ind1=np.where(t>=-t0)[0][0]
    #ind2=np.where(t<=t0)[0][-1]
    #ax.scatter(np.abs(np.array(scatter3)-68),np.array([np.max(x[k][ind1:ind2+1]) for x in scatterML]))
    inds=np.where(np.abs(tempx[inds1]-pks[k])>sigma)[0]
    ax.scatter(np.array([np.sum(np.abs(np.gradient(x[k][0][ind1:ind2+1]))) for x in np.array(scatterML)[inds1][inds]]),np.abs(tempx[inds1][inds]-pks[k]),
               color='r',label=k+r' $\Delta t>1\sigma$',marker=syms[k])
    #ax.scatter(np.abs(np.array(scatter3)[inds]-68),np.array([np.max(x[k][ind1:ind2+1]) for x in np.array(scatterML)[inds]]),color='r')

#lstsq=scipy.stats.linregress(allx[allx>.03],ally[allx>.03])
#m=lstsq[0]
#c=lstsq[1]
#R=lstsq[2]
#p=lstsq[3]
ax.set_xlim([0,1.1*np.max(np.array([np.sum(np.abs(np.gradient(x[k][0][ind1:ind2+1]))) for x in scatterML]))])
ax.set_ylim([0,np.max(ally)])
x=np.linspace(0,ax.get_xlim()[1],100)
#ax.plot(x,m*x+c,color='r',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
lstsq=scipy.stats.linregress(allx,ally)#[allx<=.03],ally[allx<=.03])
m=lstsq[0]
c=lstsq[1]
R=lstsq[2]
p=lstsq[3]
linear=interp1d(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100),m*np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)+c)
ax.plot(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100),linear(np.linspace(ax.get_xlim()[0],ax.get_xlim()[1],100)))
#from scipy.interpolate import Rbf
z=np.abs(ally-linear(allx))
sort=np.argsort(allx)
allx=allx[sort]
ally=ally[sort]

allsigs=[0]
allVals=[0]
for i in np.arange(0,len(allx),dmu):
    mean,sigma=scipy.stats.norm.fit(z[i:min(i+dmu,len(allx))])
    allsigs.append(sigma)
    allVals.append(allx[min(i+dmu,len(allx)-1)])
sigFunc=interp1d(allVals,allsigs,fill_value='extrapolate',bounds_error=False)
ax.fill_between(np.linspace(np.min(allx),np.max(allx),100),
                linear(np.linspace(np.min(allx),np.max(allx),100))+
                    3*sigFunc(np.linspace(np.min(allx),np.max(allx),100)),
                linear(np.linspace(np.min(allx),np.max(allx),100))-
                    3*sigFunc(np.linspace(np.min(allx),np.max(allx),100)),alpha=.3)
ax.plot(x,m*x+c,color='k',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
ax.set_ylabel('$\Delta t$')
ax.set_xlabel(r'$\mu-\rm{slope}$')
#ax.annotate('$R^2='+str(np.round(R**2,2))+'$',fontsize=15,xy=(.3,.9),xycoords='axes fraction')
ax.set_title('Time Delay Measurement vs. $\mu-$lensing Slope Near Peak')
ax.legend(loc='upper left',fontsize=8)
plt.show()


fig=plt.figure()
ax=fig.gca()

x_lower=np.inf
x_upper=-np.inf
y_lower=np.inf
y_upper=-np.inf
all1=[]
all2=[]
for k in ['S1','S2']:
    slope1=np.array([np.sum(np.abs(np.gradient(x[k][1]*(x[k][0][ind1:ind2+1])))) for x in scatterML])
    mu=np.array([x[k][0].mu(t)*x[k][1] for x in scatterMLmeasured])
    slope2=np.array([np.sum(np.abs(np.gradient(x[ind1:ind2+1]))) for x in mu])
    ax.scatter(slope1,slope2,marker=syms[k])
    all1=np.append(all1,slope1)
    all2=np.append(all2,slope2)
    x_lower=min(np.min(slope1),x_lower)
    x_upper=max(np.max(slope1),x_upper)
    y_lower=min(np.min(slope2),y_lower)
    y_upper=max(np.max(slope2),y_upper)
    
lstsq=scipy.stats.linregress(all1,all2)
m=lstsq[0]
c=lstsq[1]
R=lstsq[2]
p=lstsq[3]
print(m)
ax.set_xlim((.9*x_lower,1.1*x_upper))
ax.set_ylim((.9*y_lower,1.1*y_upper))
x=np.linspace(0,ax.get_xlim()[1],100)
ax.plot(x,m*x+c,color='k',label='Best Fit ('+'$R^2\simeq'+str(np.round(R**2,2))+'$)')
ax.set_xlabel('Actual Microlensing Effect')
ax.set_ylabel('Measured Microlensing Effect')
ax.set_title('Actual vs. Measured Microlensing Near Peak')
ax.legend()
plt.show()
'''
for i in range(len(scatterML)):
    for k in ['S1','S2']:
        mu=scatterMLmeasured[i][k][0].mu(t)
        fig=plt.figure()
        ax=fig.gca()
        ax.plot(t,scatterML[i][k])
        ax.plot(t,mu)
        ax.set_xlim((-5,5))
        plt.show()
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-675bb74ae66c> in <module>()
#      33 #R=lstsq[2]
#      34 #p=lstsq[3]
# ---> 35 ax.set_xlim([0,1.1*np.max(np.array([np.sum(np.abs(np.gradient(x[k][0][ind1:ind2+1]))) for x in scatterML]))])
#      36 ax.set_ylim([0,np.max(ally)])
#      37 x=np.linspace(0,ax.get_xlim()[1],100)
#
# /Users/jpierel/anaconda3/envs/sntd2/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in amax(a, axis, out, keepdims)
#    2318
#    2319     return _methods._amax(a, axis=axis,
# -> 2320                           out=out, **kwargs)
#    2321
#    2322
#
# /Users/jpierel/anaconda3/envs/sntd2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
# ...

# %%
noml=np.array([x['S2']-x['S1'] for x in scatter1])
withml=np.array([x['S2']-x['S1'] for x in scatter3])
#print(np.std(scatter1),np.std(scatter2),np.std(scatter3))
#print(np.mean(scatter1),np.mean(scatter2),np.mean(scatter3))
mean,sigma=scipy.stats.norm.fit(noml)
print(mean,sigma,np.std(noml))
mean,sigma=scipy.stats.norm.fit(withml)
print(mean,sigma,np.std(withml))
fig=plt.figure(figsize=(20,10)) 
ax=fig.gca() 

ax.hist(noml, bins=nsim/15, normed=True,label='No Microlensing')
#ax.hist(scatter2, bins=nsim/15, normed=True,label='Achromatic Microlensing $t_{pk}$',alpha=.5)
ax.hist(withml, bins=nsim/15, normed=True,label='Achromatic Microlensing $t_0$',alpha=.5)
ax.plot([68,68],ax.get_ylim(),'r--',label='Actual Time Delay') 
ax.legend(loc='upper left',fontsize=16) 
ax.set_title('Type Ib Doubly-Imaged Time Delay Measurement',size=24) 
ax.set_ylabel('Probability Density',size=20) 
ax.set_xlabel('Relative Time Delay (Days)',size=20) 
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
plt.show()
# Out:
# (67.45003924196973, 2.8683477838609126, 2.8683477838609126)
# (67.37618212303973, 2.845074562948711, 2.845074562948711)

# %%
print(np.std(noScatter1),np.std(noScatter2))
print(np.mean(noScatter1),np.mean(noScatter2))
fig=plt.figure(figsize=(20,10)) 
ax=fig.gca() 

ax.hist(noScatter1, bins=nsim/5, normed=True,label='No Microlensing')
ax.hist(noScatter2, bins=nsim/5, normed=True,label='Achromatic Microlensing',alpha=.5)
ax.plot([68,68],ax.get_ylim(),'r--',label='Actual Time Delay') 
ax.legend(loc='upper left',fontsize=16) 
ax.set_title('Type Ib Doubly-Imaged Time Delay Measurement',size=24) 
ax.set_ylabel('Probability Density',size=20) 
ax.set_xlabel('Relative Time Delay (Days)',size=20) 
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
plt.show()
# Out:
# (1.5451472770699834, 1.2638234682458813)
# (68.21202799163586, 67.95873940520457)

# %%
for i in range(2):
    fig=plt.figure()
    ax=fig.gca()
    ax.scatter([x[i] for x in stats],[x[i] for x in deltas])
    ax.set_ylim((0,.8))
    #ax.set_xlim((0,1))
    plt.show()
    plt.close()

# %%
def reddening(band):
    band=sncosmo.get_bandpass(band)
    wave, dwave = integration_grid(band.minwave(), band.maxwave(),MODEL_BANDFLUX_SPACING)
    f0=np.ones(len(wave))
    f=extinction.apply(extinction.ccm89(wave,.3,3.1),f0)
    return(np.sum(wave * band(wave) * f)/np.sum(wave*band(wave)*f0))

for i in range(len(stats)):

    if np.min(stats[i])>.5:
        continue
    print(stats[i])
    row=-1
    fig,ax=plt.subplots(nrows=2,ncols=3,sharex=False,sharey=False,figsize=(12,12))
    lcs_tdfit=all_lcs[i]
    lcs=all_orig[i]
    durb=False
    for k in lcs.images.keys():
            row+=1
            col=0
            lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['flux']>.01]
            #lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['time']>-15+lcs_tdfit.images[k].fits.model.get('t0')]
            #lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['time']<60+lcs_tdfit.images[k].fits.model.get('t0')]
            for b in bandlist:

                tempTime=lcs.images[k].table['time'][lcs.images[k].table['band']==b]-lcs_tdfit.images[k].fits.model.get('t0')
                resid=-2.5*np.log10(lcs.images[k].table['flux'][lcs.images[k].table['band']==b])+2.5*np.log10(lcs_tdfit.images[k].fits.model.bandflux(b,tempTime+lcs_tdfit.images[k].fits.model.get('t0'),
                            zpsys='AB',zp=lcs.images[k].zp[b]))
                if durbin_watson(resid)<=1 or True:
                    durb=True
                ax[row][col].scatter(tempTime,resid)
                            #1.0857 *lcs.images[k].table['fluxerr']/lcs.images[k].table['flux'],fmt='r.')
                #print((lcs.images[k].table['time']-lcs_tdfit.images[k].fits.model.get('t0')-
                #                                                 lcs_tdfit.images[k].fits.model._source._phase[0])/(1+.53))
                ml=lcs.images[k].simMeta['microlensing_params'](tempTime/(1+1.33))
                mu=lcs.images[k].simMeta['mu']
                mlDiff=lcs_tdfit.images[k].fits.model.get('amplitude')/(lcs.model.get('amplitude')*mu)
                #print(mu,lcs_tdfit.images[k].fits.model.get('amplitude')/(lcs.model.get('amplitude')),
                #     mlDiff)
                #print(-2.5*np.log10(lcs.images[k].table['flux'][lcs.images[k].table['band']==b])+lcs.images[k].table['zp'][0]+2.5*np.log10(lcs_tdfit.images[k].fits.model.bandflux(b,tempTime+lcs_tdfit.images[k].fits.model.get('t0'),
                #            zpsys='AB',zp=lcs.images[k].table['zp'][0]))-lcs.images[k].table['zp'][0])
                #sys.exit()
                #ax[row][col].plot(tempTime,(ml-np.median(ml)),label='med')
                #ax[row][col].plot(tempTime,(ml-np.mean(ml)),label='mean')
                ax[row][col].plot(tempTime,ml+2.5*np.log10(mlDiff))#+2.5*np.log10(reddening(b)))
                
                #print(durbin_watson(resid))
                #phi=testing(resid,tempTime)
                #print(phi)
                #iar=final(phi,resid,tempTime)
                #ax.plot(tempTime[:-1],iar)
                #ax.plot(tempTime,(ml-np.mean(ml)),label='mean')
                spl=splrep(tempTime,resid,s=len(tempTime)/2,k=1)
                ax[row][col].plot(tempTime,splev(tempTime,spl))
                ax[row][col].legend()
                ax[row][col].plot(ax[row][col].get_xlim(),[0,0])
                ax[row][col].invert_yaxis()
                col=1
                ax[row][col].plot(tempTime,ml)#10**(-.4*ml))
                ax[row][col].invert_yaxis()
            ax[row][2].plot(np.arange(-20,150,1),lcs.images[k].simMeta['microlensing_params'](np.arange(-20,150,1)))
            ax[row][2].invert_yaxis()    
            
    if durb:    
        plt.show()
    else:
        plt.clf()
    plt.close()

# %%
import numpy as np
from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C



# ----------------------------------------------------------------------
# now the noisy case

b='F110W'
k='S1'
#for i in range(100):
#    if np.abs(np.max(lcs.images[k].simMeta['microlensing_params'](tempTime/(1+1.33)))-
#              np.min(lcs.images[k].simMeta['microlensing_params'](tempTime/(1+1.33))))>.03:#durbin_watson(lcs.images[k].simMeta['microlensing_params'](tempTime/(1+1.33)))<.1:
#        #print(np.max(lcs.images[k].simMeta['microlensing_params'](tempTime/(1+1.33))),np.min(lcs.images[k].simMeta['microlensing_params'](tempTime/(1+1.33))))
#        break
i=0#29
lcs_tdfit=all_lcs[i]
lcs=all_orig[i]
lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['flux']>.01]
    
tempTime=lcs.images[k].table['time'][lcs.images[k].table['band']==b]-lcs_tdfit.images[k].fits.model.get('t0')
X=tempTime
resid=lcs.images[k].table['flux'][lcs.images[k].table['band']==b]/lcs_tdfit.images[k].fits.model.bandflux(b,tempTime+lcs_tdfit.images[k].fits.model.get('t0'),
            zpsys='AB',zp=lcs.images[k].zp[b])
#X = np.linspace(0.1, 9.9, 20)
X = np.atleast_2d(X).T
mlDiff=lcs_tdfit.images[k].fits.model.get('amplitude')/(lcs.model.get('amplitude')*mu)


kernel = RBF(10., (5., 40.))# C(.1, (1e-4, 10.)) * 

# Observations and noise
#y = f(X).ravel()
y=resid.ravel()
#dy = 0.5 + 1.0 * np.random.random(y.shape)
dy=lcs.images[k].table['fluxerr']/lcs.images[k].table['flux']
#noise = np.random.normal(0, dy)
#y += noise

# Instantiate a Gaussian Process model
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy ** 2,
                              n_restarts_optimizer=100)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X, y)

x = np.atleast_2d(np.linspace(np.min(tempTime), np.max(tempTime), 1000)).T
# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(x, return_std=True)
print(sigma.shape)
# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
plt.figure()
#plt.plot(X, resid, 'r:', label=u'$f(x) = x\,\sin(x)$')
plt.errorbar(X.ravel(), y, dy, fmt='r.', markersize=10, label=u'Observations')
print(x.shape,y_pred.shape)
plt.plot(x, y_pred, 'b-', label=u'Prediction')
plt.fill(np.concatenate([x, x[::-1]]),
         np.concatenate([y_pred - 1.9600 * sigma,
                        (y_pred + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.xlim(-10, 50)
plt.ylim(.8, 1.4)
plt.legend(loc='upper left')

fig=plt.figure()
ax=fig.gca()
ax.plot(tempTime,10**(-.4*lcs.images[k].simMeta['microlensing_params'](tempTime/(1+1.33)))/mlDiff)
ax.set_xlim((-10,50))
#ax.set_ylim((-.1,.1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-186-9c5d51ff6ece> in <module>()
#      18 #        break
#      19 i=0#29
# ---> 20 lcs_tdfit=all_lcs[i]
#      21 lcs=all_orig[i]
#      22 lcs.images[k].table=lcs.images[k].table[lcs.images[k].table['flux']>.01]
#
# NameError: name 'all_lcs' is not defined

# %%
import GPy
import numpy as np

plt.close()
sample_size = 5
X = np.random.uniform(0, 1., (sample_size, 1))
Y = np.sin(X) + np.random.randn(sample_size, 1)*0.05

kernel = GPy.kern.RBF(input_dim=1, variance=1., lengthscale=1.)
model = GPy.models.GPRegression(X,Y,kernel, noise_var=1)
print(X.shape,Y.shape)
testX = np.linspace(0, 1, 100).reshape(-1, 1)
print(testX.shape)
posteriorTestY = model.posterior_samples_f(testX, full_cov=True, size=3)
simY, simMse = model.predict(testX)
print(posteriorTestY.shape)
for i in range(3):

    plt.plot(testX, posteriorTestY[:,:,i])
plt.plot(X, Y, 'ok', markersize=10)
plt.plot(testX, simY - 3 * simMse ** 0.5, '--g')
plt.plot(testX, simY + 3 * simMse ** 0.5, '--g')
plt.show()
# Out:
# ((5, 1), (5, 1))
# (100, 1)
# (100, 1, 3)
