# %%
import glob,os,sys,sncosmo
#from sntd import models,fitting,io
import sntd
from astropy.io import ascii

photometry='dolphot'

if photometry=='dolphot':
    files=glob.glob(os.path.join('data','pat_refsdal',photometry,'stringent','*.dat'))
elif photometry=='hstphot':
    files=glob.glob(os.path.join('data','pat_refsdal',photometry,'*.dat'))
else:
    raise RuntimeError("Photometry not recognized.")

# %%
for f in files:
    tab=ascii.read(f)
    tab.remove_column('flag')
    tab['band']=f[f.find('_'+photometry)-5:f.find('_'+photometry)]
    tab['zp']=sn
    print(tab)
    #curve=sntd.read_data(f)
    #print(curve.table)
# Out:
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5700   96 263 0.01 F125W
# 5700  178 857 0.01 F125W
# 5701  940 500 0.02 F125W
# 5701  674 528 0.02 F125W
# 5701  534 069 0.03 F125W
# 5702  742 282 0.03 F125W
# 5702  439 460 0.01 F125W
# 5702  855 987 0.01 F125W
# 5704  689 411 0.03 F125W
# 5704  177 048 0.03 F125W
#  ...  ...      ...   ...
# 5759  174 108 0.02 F125W
# 5760  206 409 0.02 F125W
# 5760  742 287 0.02 F125W
# 5760  119 355 0.02 F125W
# 5760  190 386 0.02 F125W
# 5761  779 554 0.03 F125W
# 5761  613 077 0.02 F125W
# 5771  798 866 0.02 F125W
# 5774  766 003 0.01 F125W
# 5775  678 820 0.02 F125W
# 5778  829 153 0.02 F125W
# Length = 67 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5662   74 173 0.00 F160W
# 5701  855 629 0.02 F160W
# 5701  122 773 0.04 F160W
# 5701  783 046 0.04 F160W
# 5702  593 908 0.04 F160W
# 5702  284 864 0.01 F160W
# 5702  421 256 0.03 F160W
# 5703  958 723 0.01 F160W
# 5703   91 327 0.01 F160W
# 5703  220 685 0.01 F160W
#  ...  ...      ...   ...
# 5757  184 913 0.02 F160W
# 5758  505 344 0.03 F160W
# 5759  898 549 0.03 F160W
# 5759   51 795 0.03 F160W
# 5759  350 043 0.03 F160W
# 5760  815 702 0.03 F160W
# 5760  736 283 0.03 F160W
# 5760  308 184 0.03 F160W
# 5761   44 209 0.04 F160W
# 5771  815 138 0.03 F160W
# 5775  545 695 0.02 F160W
# Length = 66 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5701  427 894 0.01 F125W
# 5701  377 196 0.01 F125W
# 5701  532 832 0.01 F125W
# 5702  185 960 0.02 F125W
# 5702   13 175 0.02 F125W
# 5702  826 613 0.02 F125W
# 5702  815 181 0.02 F125W
# 5703  724 943 0.01 F125W
# 5703  482 353 0.01 F125W
# 5705  722 114 0.02 F125W
#  ...  ...      ...   ...
# 5760  811 107 0.02 F125W
# 5761  693 931 0.02 F125W
# 5761  458 465 0.01 F125W
# 5761   30 863 0.01 F125W
# 5761  438 197 0.02 F125W
# 5762  804 984 0.02 F125W
# 5762  385 065 0.02 F125W
# 5772  804 484 0.02 F125W
# 5775  502 957 0.01 F125W
# 5775  800 043 0.03 F125W
# 5778  893 072 0.02 F125W
# Length = 68 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5663  116 0476 0.0 F160W
# 5702  505 110 0.03 F160W
# 5702  459 413 0.02 F160W
# 5702  821 526 0.03 F160W
# 5702  706 015 0.04 F160W
# 5703  999 246 0.02 F160W
# 5703  422 336 0.02 F160W
# 5703  588 270 0.01 F160W
# 5704  821 840 0.01 F160W
# 5704   74 561 0.01 F160W
#  ...  ...      ...   ...
# 5759  318 110 0.03 F160W
# 5759  810 339 0.04 F160W
# 5760  909 021 0.04 F160W
# 5760  873 926 0.03 F160W
# 5761  175 812 0.02 F160W
# 5761  327 590 0.02 F160W
# 5761  150 953 0.02 F160W
# 5762  259 760 0.02 F160W
# 5772   59 665 0.03 F160W
# 5775  364 424 0.04 F160W
# 5775  351 296 0.03 F160W
# Length = 67 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5695  450 117 0.01 F125W
# 5695  801 639 0.01 F125W
# 5695  226 467 0.01 F125W
# 5696  257 433 0.03 F125W
# 5696  983 598 0.02 F125W
# 5697  424 072 0.02 F125W
# 5697  709 401 0.02 F125W
# 5697  478 674 0.01 F125W
# 5698  767 161 0.01 F125W
# 5699  547 271 0.02 F125W
#  ...  ...      ...   ...
# 5754  919 526 0.02 F125W
# 5755  174 099 0.02 F125W
# 5755  954 650 0.02 F125W
# 5755  196 714 0.01 F125W
# 5756  154 454 0.01 F125W
# 5756  987 797 0.01 F125W
# 5756  722 595 0.02 F125W
# 5766   36 0131 0.0 F125W
# 5769  486 338 0.01 F125W
# 5770  467 658 0.02 F125W
# 5773  572 4491 0.0 F125W
# Length = 68 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5657  307 0536 0.0 F160W
# 5696  735 174 0.03 F160W
# 5696  392 982 0.03 F160W
# 5697  402 767 0.02 F160W
# 5697  260 231 0.03 F160W
# 5697  280 150 0.02 F160W
# 5697  692 241 0.02 F160W
# 5698  524 543 0.02 F160W
# 5698   52 430 0.03 F160W
# 5699  112 488 0.01 F160W
#  ...  ...      ...   ...
# 5753  799 394 0.03 F160W
# 5753  251 249 0.03 F160W
# 5754  532 582 0.03 F160W
# 5754  132 598 0.03 F160W
# 5754  860 121 0.03 F160W
# 5755  654 527 0.03 F160W
# 5755  559 480 0.03 F160W
# 5756  262 937 0.03 F160W
# 5756  343 361 0.04 F160W
# 5766  602 946 0.02 F160W
# 5770  210 026 0.02 F160W
# Length = 65 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5699  276 247 0.01 F125W
# 5699  703 163 0.01 F125W
# 5699  561 188 0.01 F125W
# 5700  925 804 0.02 F125W
# 5700  469 845 0.02 F125W
# 5700  134 779 0.02 F125W
# 5701  438 181 0.01 F125W
# 5701  653 278 0.01 F125W
# 5701   27 066 0.01 F125W
# 5703  778 057 0.03 F125W
#  ...  ...      ...   ...
# 5758  441 087 0.03 F125W
# 5759  326 338 0.03 F125W
# 5759  362 374 0.03 F125W
# 5759   45 136 0.03 F125W
# 5759  331 529 0.02 F125W
# 5760  619 633 0.03 F125W
# 5760  274 098 0.02 F125W
# 5770  695 8990 0.0 F125W
# 5773  531 757 0.01 F125W
# 5774   75 2383 0.0 F125W
# 5777  519 254 0.02 F125W
# Length = 70 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5661  742 0940 0.0 F160W
# 5700  427 737 0.03 F160W
# 5700  232 795 0.03 F160W
# 5700    3 282 0.03 F160W
# 5701  301 281 0.04 F160W
# 5701  460 186 0.03 F160W
# 5701  883 265 0.01 F160W
# 5702  144 361 0.01 F160W
# 5702  609 846 0.01 F160W
# 5702  271 548 0.01 F160W
#  ...  ...      ...   ...
# 5756  178 136 0.03 F160W
# 5757  102 129 0.04 F160W
# 5757  338 713 0.03 F160W
# 5758  130 460 0.04 F160W
# 5758  324 533 0.04 F160W
# 5759  971 444 0.04 F160W
# 5759  671 881 0.04 F160W
# 5759   66 640 0.03 F160W
# 5760  360 238 0.03 F160W
# 5770  416 892 0.03 F160W
# 5774  627 308 0.02 F160W
# Length = 67 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5700  956 038 0.01 F125W
# 5700  739 2187 0.0 F125W
# 5700   54 0127 0.0 F125W
# 5701  758 0257 0.0 F125W
# 5701  857 960 0.01 F125W
# 5701   57 791 0.01 F125W
# 5702  799 700 0.02 F125W
# 5702   21 883 0.01 F125W
# 5702  210 1295 0.0 F125W
# 5704  484 1914 0.0 F125W
#  ...  ...      ...   ...
# 5759    4 129 0.02 F125W
# 5760    9 025 0.02 F125W
# 5760  113 862 0.01 F125W
# 5760   63 615 0.02 F125W
# 5760  388 020 0.01 F125W
# 5761  741 054 0.02 F125W
# 5761  669 295 0.02 F125W
# 5771  568 4893 0.0 F125W
# 5774    9 871 0.01 F125W
# 5775  108 376 0.01 F125W
# 5778  799 0004 0.0 F125W
# Length = 70 rows
# mhjd flux flux_err  band
# ---- ---- -------- -----
# 5662  580 046 0.02 F160W
# 5701  593 078 0.02 F160W
# 5701  658 167 0.03 F160W
# 5701  347 182 0.02 F160W
# 5702  447 800 0.02 F160W
# 5702  229 6717 0.0 F160W
# 5702   35 619 0.01 F160W
# 5703  281 104 0.01 F160W
# 5703  642 3956 0.0 F160W
# 5703  458 2324 0.0 F160W
#  ...  ...      ...   ...
# 5757  575 652 0.02 F160W
# 5758  403 670 0.03 F160W
# 5758  247 400 0.02 F160W
# 5759  411 792 0.03 F160W
# 5759  666 712 0.03 F160W
# 5760   12 652 0.02 F160W
# 5760   34 896 0.03 F160W
# 5760  581 112 0.03 F160W
# 5761  454 698 0.02 F160W
# 5771  447 386 0.02 F160W
# 5775  130 257 0.02 F160W
# Length = 67 rows
