# %%
from matplotlib import pyplot as plt
import sncosmo
from sntd import simulation, fitting,io
from sntd.plotting import _COLORLIST5
import sys
import numpy as np

# %%
reload(fitting) 
reload(simulation) 
nsim = 20
dt_fit_list = [] 
murel_fit_list = [] 

for isim in range(nsim):

    # Part 1 : simulate a doubly-imaged Type Ib SN and fit for time delays
    modname = 'snana-2004gv'
    snType = 'Ib'
    #bandlist = ['bessellb', 'bessellv', 'bessellr']
    bandlist = ['F125W']
    lcs = simulation.createMultiplyImagedSN(
        modname, snType, 1.3, bands=bandlist,
        zp=27., cadence=10., epochs=5.,skynoiseRange=(.1,2), mjdRange=[0,100.], time_delays=[0., 15.],
        magnifications=[10.,20.], objectName='Test'+snType, telescopename='HST',
        z_lens=0.5, microlensing_type='AchromaticSplineMicrolensing',
        microlensing_params=[4,2,50],minsnr=5.0)
    print(lcs.images['S1'].simMeta)
    ifig = 0
    print("Simulated strongly lensed SN %i"%isim)
    #lcs.plot_object(showfig=True,savefig=False)

    # Part 2: fit each light curve separately to determine lensing parameters
    lcs_tdfit=fitting.fit_data(lcs, snType='Ib', models=['snana-2004gv'],dust='CCM89Dust',effect_frames=['rest'],
                                effect_names=['host'],
                                params=['z','amplitude','t0','hostebv'],
                                bounds={'hostebv':(0,1),'z':(1.28,1.32),'t0':(-10,10)},
                                combined_or_separate='separate',
                                method='minuit')



    # TODO: make this more general, i.e. use keywords list instead of s1 and s2.
    #t0_s1 = lcs_tdfit.images['S1'].fits.model.get('t0')
    #t0_s2 = lcs_tdfit.images['S2'].fits.model.get('t0')
    print(np.abs(lcs_tdfit.time_delays['S2']))
    #A_s1 = lcs_tdfit.images['S1'].fits.model.get('amplitude')
    #A_s2 = lcs_tdfit.images['S2'].fits.model.get('amplitude')
    dt_fit_list.append(np.abs(lcs_tdfit.time_delays['S2']))
    murel_fit_list.append(A_s2/A_s1)
    #plt.plot(dt_fit_list, murel_fit_list,marker='o', color=_COLORLIST5[3], ls=' ')
fig=plt.figure(figsize=(20,10)) 
ax=fig.gca() 
ax.hist(dt_fit_list, bins=nsim/5, normed=True,label='Measured Time Delay')

ax.plot([15,15],ax.get_ylim(),'r--',label='Actual Time Delay') 
ax.legend(loc='upper left',fontsize=16) 
ax.set_title('Type Ib Doubly-Imaged Time Delay Measurement--N=100',size=24) 
ax.set_ylabel('Probability Density',size=20) 
ax.set_xlabel('Relative Time Delay (Days)',size=20) 
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)

plt.show()
plt.close()
# Out:
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 2.560146803513123e-17, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11b1f1050>, 'model': <sncosmo.models.Model object at 0x11b1f18d0>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 0
# 16.959467712490934
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 4.267861131198773e-17, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11cdf74d0>, 'model': <sncosmo.models.Model object at 0x11cdf7c10>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 1
# 14.206378747926752
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 2.49306923250372e-17, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11c9eb990>, 'model': <sncosmo.models.Model object at 0x11c9ebfd0>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 2
# 16.298725356736995
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 6.120832911468345e-18, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11c9243d0>, 'model': <sncosmo.models.Model object at 0x11c924f10>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 3
# 15.535174541113975
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 8.373775966152472e-18, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11c8b33d0>, 'model': <sncosmo.models.Model object at 0x11cc0dbd0>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 4
# 18.38060078020866
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 1.357775129443119e-17, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11ae36850>, 'model': <sncosmo.models.Model object at 0x11ae36610>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 5
# 14.695191502618455
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 5.77502371835501e-17, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11c324050>, 'model': <sncosmo.models.Model object at 0x11c3244d0>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 6
# 14.457361994680406
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 1.4270388107003842e-17, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11c3527d0>, 'model': <sncosmo.models.Model object at 0x11c352d10>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 7
# 15.866532884258703
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 3.971108130962087e-18, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11ccdbf50>, 'model': <sncosmo.models.Model object at 0x11ccdb590>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 8
# 16.092199693435788
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 2.1297396321822643e-18, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11c787590>, 'model': <sncosmo.models.Model object at 0x11c787350>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 9
# 4.896123656023299
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 7.167550402196636e-18, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11cd25710>, 'model': <sncosmo.models.Model object at 0x11ccdbe10>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 10
# 15.388645030102804
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 5.6937601664238404e-18, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11ceb1f50>, 'model': <sncosmo.models.Model object at 0x11ceb1090>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 11
# 10.975904547879663
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 6.268972599209123e-18, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11c4e2650>, 'model': <sncosmo.models.Model object at 0x11c4e2e90>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 12
# 15.923586445645645
# {'lensz': 0.5, 'lensebv': 0, 't0': 12.5, 'mu': 10.0, 'microlensing_params': [4, 2, 50], 'hostebv': 0.0967741935483871, 'amplitude': 2.230475735559113e-17, 'microlensing': <sncosmo.models.AchromaticSplineMicrolensing object at 0x11cca7390>, 'model': <sncosmo.models.Model object at 0x11cca7e90>, 'z': 1.3, 'td': 0.0, 'microlensing_type': 'AchromaticSplineMicrolensing', 'microlensingz': 0.5}
# Simulated strongly lensed SN 13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-78e38db84e1a> in <module>()
#      29                                 bounds={'hostebv':(0,1),'z':(1.28,1.32),'t0':(-10,10)},
#      30                                 combined_or_separate='separate',
# ---> 31                                 method='minuit')
#      32
#      33
#
# /Users/jpierel/rodney/sntd/sntd/fitting.pyc in fit_data(lcs, snType, bands, method, models, params, bounds, ignore, constants, spline, poly, micro, combined_or_separate, combinedGrids, **kwargs)
#     180         raise RuntimeError('Parameter "combined_or_separate must be "separate","combined", or "both".')
#     181     if combined_or_separate=='separate':
# --> 182         curves=_fitSeparate(curves,mods,args,bounds)
#     183     elif combined_or_separate=='combined':
#     184         curves=_fitCombined(curves,mods,args,bounds,combinedGrids)
#
# /Users/jpierel/rodney/sntd/sntd/fitting.pyc in _fitSeparate(curves, mods, args, bounds)
#     709         else:
#     710             guess_amp_bounds=False
# --> 711         nest_res,nest_fit=sncosmo.nest_lc(tempTable,bestFit,vparam_names=bestRes.vparam_names,bounds=args['bounds'],guess_amplitude_bound=guess_amp_bounds,maxiter=1000,npoints=200)
#     712         #print(d,nest_res.h)
#     713
#
# /Users/jpierel/anaconda3/envs/sntd2/lib/python2.7/site-packages/sncosmo-1.6.0-py2.7-macosx-10.7-x86_64.egg/sncosmo/fitting.pyc in nest_lc(data, model, vparam_names, bounds, guess_amplitude_bound, minsnr, priors, ppfs, npoints, method, maxiter, maxcall, modelcov, rstate, verbose, warn, **kwargs)
#     916                         npoints=npoints, method=method, maxiter=maxiter,
#     917                         maxcall=maxcall, rstate=rstate,
# --> 918                         callback=(nestle.print_progress if verbose else None))
#     919     elapsed = time.time() - t0
#     920
#
# /Users/jpierel/anaconda3/envs/sntd2/lib/python2.7/site-packages/nestle.pyc in sample(loglikelihood, prior_transform, ndim, npoints, method, update_interval, npdim, maxiter, maxcall, dlogz, decline_factor, rstate, callback, **options)
#     927         # Choose a new point from within the likelihood constraint
#     928         # (having logl > loglstar).
# --> 929         u, v, logl, nc = sampler.new_point(loglstar)
#     930
#     931         # replace worst point with new point
#
# /Users/jpierel/anaconda3/envs/sntd2/lib/python2.7/site-packages/nestle.pyc in new_point(self, loglstar)
#     639                 if np.all(u > 0.) and np.all(u < 1.):
#     640                     break
# --> 641             v = self.prior_transform(u)
#     642             logl = self.loglikelihood(v)
#     643             ncall += 1
#
# /Users/jpierel/anaconda3/envs/sntd2/lib/python2.7/site-packages/sncosmo-1.6.0-py2.7-macosx-10.7-x86_64.egg/sncosmo/fitting.pyc in prior_transform(u)
#     895         d = {}
#     896         for i in range(npdim):
# --> 897             d[iparam_names[i]] = ppflist[i](u[i])
#     898         v = np.empty(ndim, dtype=np.float)
#     899         for i in range(ndim):
#
# KeyboardInterrupt:
